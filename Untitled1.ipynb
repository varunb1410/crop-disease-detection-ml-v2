# %%
import tensorflow as tf

model = tf.keras.models.load_model(
    "saved_model",
    compile=False
)

model.save("final_model.h5")

print("H5 model saved successfully")
# Out:
# ---------------------------------------------------
# ValueError        Traceback (most recent call last)
# Cell In[1], line 3
#       1 import tensorflow as tf
# ----> 3 model = tf.keras.models.load_model(
#       4     "saved_model",
#       5     compile=False
#       6 )
#       8 model.save("final_model.h5")
#      10 print("H5 model saved successfully")
#
# File D:\major project\crop_disease_prediction_v2\venv\Lib\site-packages\keras\src\saving\saving_api.py:209, in load_model(filepath, custom_objects, compile, safe_mode)
#     203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#     208 else:
# --> 209     raise ValueError(
#     210         f"File format not supported: filepath={filepath}. "
#     211         "Keras 3 only supports V3 `.keras` files and "
#     212         "legacy H5 format files (`.h5` extension). "
#     213         "Note that the legacy SavedModel format is not "
#     214         "supported by `load_model()` in Keras 3. In "
#     215         "order to reload a TensorFlow SavedModel as an "
#     216         "inference-only layer in Keras 3, use "
#     217         "`keras.layers.TFSMLayer("
#     218         f"{filepath}, call_endpoint='serving_default')` "
#     219         "(note that your `call_endpoint` "
#     220         "might have a different name)."
#     221     )
#
# ValueError: File format not supported: filepath=saved_model. Keras 3 only supports V3 `.keras` files and legacy H5 format files (`.h5` extension). Note that the legacy SavedModel format is not supported by `load_model()` in Keras 3. In order to reload a TensorFlow SavedModel as an inference-only layer in Keras 3, use `keras.layers.TFSMLayer(saved_model, call_endpoint='serving_default')` (note that your `call_endpoint` might have a different name).
